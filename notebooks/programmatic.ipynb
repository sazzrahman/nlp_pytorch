# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import re
sys.path.append("../helper")

# %%
# %load_ext autoreload
# %autoreload 2
from presto_con import PrestoQuery, PrestoAlchemy
from dtype_parser import DtypeParse
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pq = PrestoQuery()
query = "SHOW TABLES"
pq.pquery(query)
# Out:
#                                            Table
# 0         brand_safety_platform_connection_sites
# 1    brand_safety_platform_connection_sites_test
# 2   brand_safety_platform_connection_sites_test2
# 3                             brand_safety_sites
# 4                        brand_safety_sites_test
# 5                      ceph_tracker_expanded_ssp
# 6                     tracker_agg1_eastern_daily
# 7                         tracker_agg1_utc_daily
# 8                        tracker_agg1_utc_hourly
# 9                    tracker_agg1_utc_hourly_agg
# 10                   tracker_agg1_utc_hourly_dev
# 11            tracker_audience_agg_eastern_daily
# 12                tracker_audience_agg_utc_daily
# 13               tracker_audience_agg_utc_hourly
# 14           tracker_audience_agg_utc_hourly_agg
# 15               tracker_basic_agg_eastern_daily
# 16                   tracker_basic_agg_utc_daily
# 17                  tracker_basic_agg_utc_hourly
# ...

# %%
pq = PrestoQuery()

# %%
query = "SELECT * FROM tracker_programmatic_agg_eastern_daily WHERE date(daydate) > date('2019-01-01') LIMIT 100000"
df = pq.pquery(query)

# %%
df.to_feather("../data/programmatic")

# %%
df.shape
# Out:
# (100000, 90)

# %%
df.dtypes
# Out:
# publisher_id                           int64
# parent_publisher_id                   object
# site_id                                int64
# parent_site_id                        object
# ad_source_id                         float64
# ad_deal_id                           float64
# ad_tag_id                            float64
# environment_id                         int64
# domain                                object
# app_name                              object
# bundle_id                             object
# media_file_duration                  float64
# programmatic_buyer_id                float64
# rtb_seat_id                           object
# rtb_advertiser_domain                 object
# rtb_creative_id                       object
# supply_partner_id                      int64
# rtb_campaign_id                       object
# rtb_deal_id                           object
# rtb_bid_response_timeout_count         int64
# rtb_syncable_user_bid_requests         int64
# ...

# %%
# They were never used. 
dp = DtypeParse(df)
dp.parse_objects()
# Out:
# parent_publisher_id      object
# parent_site_id           object
# domain                   object
# app_name                 object
# bundle_id                object
# rtb_seat_id              object
# rtb_advertiser_domain    object
# rtb_creative_id          object
# rtb_campaign_id          object
# rtb_deal_id              object
# ad_type                  object
# daydate                  object
# dtype: object

# %%
dp.parse_sparsity()
# Out:
# publisher_id                         0.00000
# site_id                              0.00000
# environment_id                       0.00000
# media_file_duration                  0.00000
# supply_partner_id                    0.00000
# ad_order_id                          0.00000
# ad_source_id                         0.02568
# ad_deal_id                           0.02568
# ad_tag_id                            0.02568
# ad_request_count                     0.14358
# tag_error_count                      0.63248
# programmatic_buyer_id                0.63673
# vpaid_initad_count                   0.85795
# vpaid_startad_count                  0.95411
# ad_opportunity_count                 0.97432
# vpaid_opt_out_count                  0.98213
# ad_timeout_count                     0.99548
# vpaid_compatible_impression_count    0.99913
# revenue                              0.99913
# avg_winning_bid_cpm                  0.99913
# ad_start_count                       0.99913
# ...

# %%
dp.parse_bool()
# Out:
# Series([], dtype: float64)

# %%
df["cpm"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/miniconda3-4.3.30/envs/mch8ds/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cpm'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-c84c87f25c09> in <module>
# ...
